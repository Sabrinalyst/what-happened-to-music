# %%
print('Hallo')
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'portfolio (3.12.13) (Python 3.12.13)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print('Hallo')

# %%
print('Hallo')
# Out:
# Hallo
